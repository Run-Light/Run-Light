# %%
import numpy as np
from scipy.io import loadmat  # this is the SciPy module that loads mat-files
import matplotlib.pyplot as plt
from datetime import datetime, date, time
from conversion import conversion_tot
fil=10
data = loadmat('DATATESTRAW.mat')
conversion_tot(data)
# Out:
#         index  nb_seance  nb_passage  x_lumbar  y_lumbar  z_lumbar   x_tibia  \
# 0           0        0.0         0.0 -0.473048  0.027055  0.136844 -0.490409
# 1           1        0.0         0.0 -0.472116  0.026439  0.138892 -0.487774
# 2           2        0.0         0.0 -0.471199  0.025821  0.140955 -0.485119
# 3           3        0.0         0.0 -0.470297  0.025195  0.143024 -0.482449
# 4           4        0.0         0.0 -0.469405  0.024558  0.145097 -0.479768
# ...       ...        ...         ...       ...       ...       ...       ...
# 499995   4995        9.0         9.0 -1.317427 -0.043538 -0.015511 -0.780425
# 499996   4996        9.0         9.0 -1.318809 -0.042980 -0.015105 -0.780015
# 499997   4997        9.0         9.0 -1.320188 -0.042426 -0.014688 -0.779577
# 499998   4998        9.0         9.0 -1.321567 -0.041871 -0.014259 -0.779112
# 499999   4999        9.0         9.0 -1.322948 -0.041311 -0.013823 -0.778623
#
#          y_tibia   z_tibia   x_force   y_force    z_force
# 0      -0.357347 -0.567686  1.057183 -8.941128  31.378262
# 1      -0.358175 -0.562642  1.183851 -8.263459  32.026108
# 2      -0.359017 -0.557624  1.308062 -7.649749  32.628689
# 3      -0.359871 -0.552635  1.429992 -7.098335  33.187741
# 4      -0.360735 -0.547680  1.549815 -6.607554  33.704999
# ...          ...       ...       ...       ...        ...
# 499995  0.463885  1.604113  1.760153  9.349373  29.099964
# 499996  0.461618  1.603329  1.784167  9.327843  28.656276
# 499997  0.459348  1.602530  1.807832  9.308552  28.183878
# 499998  0.457075  1.601721  1.831152  9.291537  27.681607
# 499999  0.454804  1.600901  1.854130  9.276836  27.148298
#
# [500000 rows x 12 columns]

# %%
# test
